# %%
import numpy as np
import json
import tensorflow.keras as keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
dataset = "data.json"
mapping = {0:"aldfly",1:"ameavo",2:"amebit"}
#Load the dataset
def load_data(dataset_path): #dataset_path is a json file
    with open(dataset_path, "r") as hd:
        feature_data = json.load(hd)
    inputs = np.array(feature_data["mfcc"])
    target = np.array(feature_data["labels"])
    return inputs, target

#Split the data
def data_split(test_size, val_size):
    x, y = load_data(dataset)
    #Split the train examples
    x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = test_size)
    
    #Split the validation samples
    x_train, x_val, y_train, y_val = train_test_split(x_train,y_train, test_size = val_size)

    
    return x_train, x_val, x_test, y_train, y_val, y_test

def build(shape):
    #Build CNN
    model = keras.Sequential()

    model.add(keras.layers.LSTM(128, input_shape= shape, return_sequences=True))
    model.add(keras.layers.LSTM(128))

    # dense layer
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout(0.2))

    # output layer
    model.add(keras.layers.Dense(3, activation='softmax'))
    
    return model

def predict(x, y, model):
    
    x = x[np.newaxis, ...] #Make the sample number = 1

    #prediction
    prediction = model.predict(x)
    predicted_pos = np.argmax(prediction, axis=1)
    print("Target: {}, Predicted label: {}".format(mapping[y], mapping[predicted_pos[0]]))
    
if __name__ == "__main__":
    x_train, x_val, x_test, y_train, y_val, y_test = data_split(0.2,0.2)
    
    #Build the CNN
    shape = (x_train.shape[1], x_train.shape[2])
    model = build(shape)
    
    optimizer = keras.optimizers.Adam(learning_rate = 0.0001)
    model.compile(optimizer,loss = "sparse_categorical_crossentropy", metrics = ["accuracy"])
    model.summary()
    
    model.fit(x_train,y_train,validation_data = (x_val,y_val),epochs = 50, batch_size = 50)
    x_predict = x_test[5]
    y_predict = y_test[5]
    actual = predict(x_predict,y_predict,model)
    model.save("birdcall_CNN.h5")
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 173, 128)          72704
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dense_14 (Dense)             (None, 32)                4128
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 99
# =================================================================
# Total params: 208,515
# Trainable params: 208,515
# Non-trainable params: 0
# _________________________________________________________________
# Train on 115 samples, validate on 29 samples
# Epoch 1/50
# 115/115 [==============================] - 6s 54ms/sample - loss: 1.1419 - accuracy: 0.2957 - val_loss: 1.0825 - val_accuracy: 0.4138
# Epoch 2/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 1.1094 - accuracy: 0.3478 - val_loss: 1.0390 - val_accuracy: 0.5172
# Epoch 3/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 1.0348 - accuracy: 0.5130 - val_loss: 0.9994 - val_accuracy: 0.6207
# Epoch 4/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 1.0096 - accuracy: 0.5652 - val_loss: 0.9627 - val_accuracy: 0.6207
# Epoch 5/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.9765 - accuracy: 0.5652 - val_loss: 0.9273 - val_accuracy: 0.6207
# Epoch 6/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.9459 - accuracy: 0.6261 - val_loss: 0.8935 - val_accuracy: 0.6207
# Epoch 7/50
# 115/115 [==============================] - 1s 12ms/sample - loss: 0.9325 - accuracy: 0.5913 - val_loss: 0.8591 - val_accuracy: 0.6552
# Epoch 8/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.9070 - accuracy: 0.5826 - val_loss: 0.8265 - val_accuracy: 0.6552
# Epoch 9/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.8732 - accuracy: 0.6870 - val_loss: 0.7933 - val_accuracy: 0.7241
# Epoch 10/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.8152 - accuracy: 0.7391 - val_loss: 0.7597 - val_accuracy: 0.8621
# Epoch 11/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.8066 - accuracy: 0.7043 - val_loss: 0.7265 - val_accuracy: 0.8966
# Epoch 12/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.7953 - accuracy: 0.7043 - val_loss: 0.6946 - val_accuracy: 0.9310
# Epoch 13/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.7389 - accuracy: 0.7565 - val_loss: 0.6630 - val_accuracy: 0.9310
# Epoch 14/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.7068 - accuracy: 0.8174 - val_loss: 0.6315 - val_accuracy: 0.9310
# Epoch 15/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.6820 - accuracy: 0.8000 - val_loss: 0.6005 - val_accuracy: 0.9310
# Epoch 16/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.6784 - accuracy: 0.7565 - val_loss: 0.5688 - val_accuracy: 0.9310
# Epoch 17/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.6489 - accuracy: 0.7739 - val_loss: 0.5381 - val_accuracy: 0.9655
# Epoch 18/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.6235 - accuracy: 0.8087 - val_loss: 0.5093 - val_accuracy: 0.9655
# Epoch 19/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.6076 - accuracy: 0.7739 - val_loss: 0.4821 - val_accuracy: 0.9655
# Epoch 20/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.5395 - accuracy: 0.8087 - val_loss: 0.4553 - val_accuracy: 0.9655
# Epoch 21/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.5497 - accuracy: 0.8261 - val_loss: 0.4296 - val_accuracy: 0.9655
# Epoch 22/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.5242 - accuracy: 0.8174 - val_loss: 0.4053 - val_accuracy: 0.9655
# Epoch 23/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.4867 - accuracy: 0.8435 - val_loss: 0.3824 - val_accuracy: 0.9655
# Epoch 24/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.4734 - accuracy: 0.8522 - val_loss: 0.3617 - val_accuracy: 0.9655
# Epoch 25/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.4513 - accuracy: 0.8348 - val_loss: 0.3441 - val_accuracy: 0.9655
# Epoch 26/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.4176 - accuracy: 0.8783 - val_loss: 0.3259 - val_accuracy: 0.9655
# Epoch 27/50
# 115/115 [==============================] - 1s 12ms/sample - loss: 0.3997 - accuracy: 0.8348 - val_loss: 0.3065 - val_accuracy: 0.9655
# Epoch 28/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.3820 - accuracy: 0.8609 - val_loss: 0.2861 - val_accuracy: 0.9655
# Epoch 29/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.3663 - accuracy: 0.8696 - val_loss: 0.2687 - val_accuracy: 0.9655
# Epoch 30/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.3722 - accuracy: 0.8609 - val_loss: 0.2448 - val_accuracy: 0.9310
# Epoch 31/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.3506 - accuracy: 0.8609 - val_loss: 0.2276 - val_accuracy: 1.0000
# Epoch 32/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.3285 - accuracy: 0.8783 - val_loss: 0.2153 - val_accuracy: 1.0000
# Epoch 33/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2995 - accuracy: 0.9130 - val_loss: 0.2118 - val_accuracy: 1.0000
# Epoch 34/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2549 - accuracy: 0.9565 - val_loss: 0.2069 - val_accuracy: 1.0000
# Epoch 35/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2504 - accuracy: 0.9478 - val_loss: 0.1945 - val_accuracy: 1.0000
# Epoch 36/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2479 - accuracy: 0.9739 - val_loss: 0.1793 - val_accuracy: 1.0000
# Epoch 37/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2315 - accuracy: 0.9391 - val_loss: 0.1607 - val_accuracy: 1.0000
# Epoch 38/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.2123 - accuracy: 0.9565 - val_loss: 0.1458 - val_accuracy: 1.0000
# Epoch 39/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1847 - accuracy: 0.9652 - val_loss: 0.1333 - val_accuracy: 1.0000
# Epoch 40/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1737 - accuracy: 0.9652 - val_loss: 0.1268 - val_accuracy: 1.0000
# Epoch 41/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1534 - accuracy: 0.9739 - val_loss: 0.1191 - val_accuracy: 1.0000
# Epoch 42/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1353 - accuracy: 0.9826 - val_loss: 0.1116 - val_accuracy: 1.0000
# Epoch 43/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1213 - accuracy: 0.9826 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 44/50
# 115/115 [==============================] - 1s 12ms/sample - loss: 0.1070 - accuracy: 0.9826 - val_loss: 0.0898 - val_accuracy: 1.0000
# Epoch 45/50
# 115/115 [==============================] - 1s 12ms/sample - loss: 0.1109 - accuracy: 0.9826 - val_loss: 0.1074 - val_accuracy: 0.9655
# Epoch 46/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.0973 - accuracy: 0.9913 - val_loss: 0.1258 - val_accuracy: 0.9655
# Epoch 47/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 1.0000
# Epoch 48/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.1065 - accuracy: 0.9826 - val_loss: 0.0503 - val_accuracy: 1.0000
# Epoch 49/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.0801 - accuracy: 0.9913 - val_loss: 0.0460 - val_accuracy: 1.0000
# Epoch 50/50
# 115/115 [==============================] - 1s 11ms/sample - loss: 0.0570 - accuracy: 0.9913 - val_loss: 0.1330 - val_accuracy: 0.9655
# Target: aldfly, Predicted label: aldfly
